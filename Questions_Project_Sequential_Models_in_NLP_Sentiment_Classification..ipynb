# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1UXScsVx_Wni_JuDdB8LeTnM6jsPfIwkW)
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Sentiment Classification

# %% [markdown]
# ### Dataset
# - Dataset of 50,000 movie reviews from IMDB, labeled by sentiment positive (1) or negative (0)
# - Reviews have been preprocessed, and each review is encoded as a sequence of word indexes (integers).
# - For convenience, words are indexed by overall frequency in the dataset, so that for instance the integer "3" encodes the 3rd most frequent word in the data. This allows for quick filtering operations such as: "only consider the top 10,000 most common words, but eliminate the top 20 most common words".
# - As a convention, "0" does not stand for a specific word, but instead is used to encode any unknown word.
#
# Command to import data
# - `from tensorflow.keras.datasets import imdb`

# %% [markdown]
# ### Import the data (2 Marks)
# - Use `imdb.load_data()` method
# - Get train and test set
# - Take 10000 most frequent words

# %%
#### Add your code here ####

import tensorflow as tf
tf.version
# Out:
# <module 'tensorflow._api.v2.version' from '/usr/local/lib/python3.7/dist-packages/tensorflow/_api/v2/version/__init__.py'>

# %%
from tensorflow.python.eager.context import internal_operation_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from tensorflow.keras.datasets import imdb

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data(
    num_words=10000,
    seed=142,
    skip_top=20
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
len(y_train), len(y_test)
# Out:
# (25000, 25000)

# %%
# Concatenating the train and test set into a single array
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)

# %%
len(X), len(y)
# Out:
# (50000, 50000)

# %% [markdown]
# ### Pad each sentence to be of same length (2 Marks)
# - Take maximum sequence length as 300

# %%
#### Add your code here ####
print(len(X[2]))
print(len(X[3]))
print(len(X[100]))
# Out:
# 215
# 59
# 950

# %%
# max sequence length is 

n = 0
i=0
for i in X:
  j = len(i)
  if j>n:
    n = j
print('max length of reviews is', n)
# Out:
# max length of reviews is 2494

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_padded = pad_sequences(
    X,
    maxlen=300,
    padding='pre',
    truncating='pre',
)

# %% [markdown]
# ### Print shape of features & labels (2 Marks)

# %% [markdown]
# Number of review, number of words in each review

# %%
print('Number of reviews = ', len(X_padded))
# Out:
# Number of reviews =  50000

# %%
## Words in each review
index = 1
for i in X_padded:
  print('Number of words in review', index, 'is', len(i))
  index = index+1
# Out:
# Streaming output truncated to the last 5000 lines.
# Number of words in review 45001 is 300
# Number of words in review 45002 is 300
# Number of words in review 45003 is 300
# Number of words in review 45004 is 300
# Number of words in review 45005 is 300
# Number of words in review 45006 is 300
# Number of words in review 45007 is 300
# Number of words in review 45008 is 300
# Number of words in review 45009 is 300
# Number of words in review 45010 is 300
# Number of words in review 45011 is 300
# Number of words in review 45012 is 300
# Number of words in review 45013 is 300
# Number of words in review 45014 is 300
# Number of words in review 45015 is 300
# Number of words in review 45016 is 300
# Number of words in review 45017 is 300
# Number of words in review 45018 is 300
# Number of words in review 45019 is 300
# Number of words in review 45020 is 300
# Number of words in review 45021 is 300
# Number of words in review 45022 is 300
# Number of words in review 45023 is 300
# Number of words in review 45024 is 300
# Number of words in review 45025 is 300
# Number of words in review 45026 is 300
# Number of words in review 45027 is 300
# Number of words in review 45028 is 300
# Number of words in review 45029 is 300
# Number of words in review 45030 is 300
# Number of words in review 45031 is 300
# Number of words in review 45032 is 300
# Number of words in review 45033 is 300
# Number of words in review 45034 is 300
# Number of words in review 45035 is 300
# Number of words in review 45036 is 300
# Number of words in review 45037 is 300
# Number of words in review 45038 is 300
# Number of words in review 45039 is 300
# Number of words in review 45040 is 300
# Number of words in review 45041 is 300
# Number of words in review 45042 is 300
# Number of words in review 45043 is 300
# Number of words in review 45044 is 300
# Number of words in review 45045 is 300
# Number of words in review 45046 is 300
# Number of words in review 45047 is 300
# Number of words in review 45048 is 300
# Number of words in review 45049 is 300
# Number of words in review 45050 is 300
# Number of words in review 45051 is 300
# Number of words in review 45052 is 300
# Number of words in review 45053 is 300
# Number of words in review 45054 is 300
# Number of words in review 45055 is 300
# Number of words in review 45056 is 300
# Number of words in review 45057 is 300
# Number of words in review 45058 is 300
# Number of words in review 45059 is 300
# Number of words in review 45060 is 300
# Number of words in review 45061 is 300
# Number of words in review 45062 is 300
# Number of words in review 45063 is 300
# Number of words in review 45064 is 300
# Number of words in review 45065 is 300
# Number of words in review 45066 is 300
# Number of words in review 45067 is 300
# Number of words in review 45068 is 300
# Number of words in review 45069 is 300
# Number of words in review 45070 is 300
# Number of words in review 45071 is 300
# Number of words in review 45072 is 300
# Number of words in review 45073 is 300
# Number of words in review 45074 is 300
# Number of words in review 45075 is 300
# Number of words in review 45076 is 300
# Number of words in review 45077 is 300
# Number of words in review 45078 is 300
# Number of words in review 45079 is 300
# Number of words in review 45080 is 300
# Number of words in review 45081 is 300
# Number of words in review 45082 is 300
# Number of words in review 45083 is 300
# Number of words in review 45084 is 300
# Number of words in review 45085 is 300
# Number of words in review 45086 is 300
# Number of words in review 45087 is 300
# Number of words in review 45088 is 300
# Number of words in review 45089 is 300
# Number of words in review 45090 is 300
# Number of words in review 45091 is 300
# Number of words in review 45092 is 300
# Number of words in review 45093 is 300
# Number of words in review 45094 is 300
# Number of words in review 45095 is 300
# Number of words in review 45096 is 300
# Number of words in review 45097 is 300
# Number of words in review 45098 is 300
# Number of words in review 45099 is 300
# Number of words in review 45100 is 300
# Number of words in review 45101 is 300
# Number of words in review 45102 is 300
# Number of words in review 45103 is 300
# Number of words in review 45104 is 300
# Number of words in review 45105 is 300
# Number of words in review 45106 is 300
# Number of words in review 45107 is 300
# Number of words in review 45108 is 300
# Number of words in review 45109 is 300
# Number of words in review 45110 is 300
# Number of words in review 45111 is 300
# Number of words in review 45112 is 300
# Number of words in review 45113 is 300
# Number of words in review 45114 is 300
# Number of words in review 45115 is 300
# Number of words in review 45116 is 300
# Number of words in review 45117 is 300
# Number of words in review 45118 is 300
# Number of words in review 45119 is 300
# Number of words in review 45120 is 300
# Number of words in review 45121 is 300
# Number of words in review 45122 is 300
# Number of words in review 45123 is 300
# Number of words in review 45124 is 300
# Number of words in review 45125 is 300
# Number of words in review 45126 is 300
# Number of words in review 45127 is 300
# Number of words in review 45128 is 300
# Number of words in review 45129 is 300
# Number of words in review 45130 is 300
# Number of words in review 45131 is 300
# Number of words in review 45132 is 300
# Number of words in review 45133 is 300
# Number of words in review 45134 is 300
# Number of words in review 45135 is 300
# Number of words in review 45136 is 300
# Number of words in review 45137 is 300
# Number of words in review 45138 is 300
# Number of words in review 45139 is 300
# Number of words in review 45140 is 300
# Number of words in review 45141 is 300
# Number of words in review 45142 is 300
# Number of words in review 45143 is 300
# Number of words in review 45144 is 300
# Number of words in review 45145 is 300
# Number of words in review 45146 is 300
# Number of words in review 45147 is 300
# Number of words in review 45148 is 300
# Number of words in review 45149 is 300
# Number of words in review 45150 is 300
# Number of words in review 45151 is 300
# Number of words in review 45152 is 300
# Number of words in review 45153 is 300
# Number of words in review 45154 is 300
# Number of words in review 45155 is 300
# Number of words in review 45156 is 300
# Number of words in review 45157 is 300
# Number of words in review 45158 is 300
# Number of words in review 45159 is 300
# Number of words in review 45160 is 300
# Number of words in review 45161 is 300
# Number of words in review 45162 is 300
# Number of words in review 45163 is 300
# Number of words in review 45164 is 300
# Number of words in review 45165 is 300
# Number of words in review 45166 is 300
# Number of words in review 45167 is 300
# Number of words in review 45168 is 300
# Number of words in review 45169 is 300
# Number of words in review 45170 is 300
# Number of words in review 45171 is 300
# Number of words in review 45172 is 300
# Number of words in review 45173 is 300
# Number of words in review 45174 is 300
# Number of words in review 45175 is 300
# Number of words in review 45176 is 300
# Number of words in review 45177 is 300
# Number of words in review 45178 is 300
# Number of words in review 45179 is 300
# Number of words in review 45180 is 300
# Number of words in review 45181 is 300
# Number of words in review 45182 is 300
# Number of words in review 45183 is 300
# Number of words in review 45184 is 300
# Number of words in review 45185 is 300
# Number of words in review 45186 is 300
# Number of words in review 45187 is 300
# Number of words in review 45188 is 300
# Number of words in review 45189 is 300
# Number of words in review 45190 is 300
# Number of words in review 45191 is 300
# Number of words in review 45192 is 300
# Number of words in review 45193 is 300
# Number of words in review 45194 is 300
# Number of words in review 45195 is 300
# Number of words in review 45196 is 300
# Number of words in review 45197 is 300
# Number of words in review 45198 is 300
# Number of words in review 45199 is 300
# Number of words in review 45200 is 300
# Number of words in review 45201 is 300
# Number of words in review 45202 is 300
# Number of words in review 45203 is 300
# Number of words in review 45204 is 300
# Number of words in review 45205 is 300
# Number of words in review 45206 is 300
# Number of words in review 45207 is 300
# Number of words in review 45208 is 300
# Number of words in review 45209 is 300
# Number of words in review 45210 is 300
# Number of words in review 45211 is 300
# Number of words in review 45212 is 300
# Number of words in review 45213 is 300
# Number of words in review 45214 is 300
# Number of words in review 45215 is 300
# Number of words in review 45216 is 300
# Number of words in review 45217 is 300
# Number of words in review 45218 is 300
# Number of words in review 45219 is 300
# Number of words in review 45220 is 300
# Number of words in review 45221 is 300
# Number of words in review 45222 is 300
# Number of words in review 45223 is 300
# Number of words in review 45224 is 300
# Number of words in review 45225 is 300
# Number of words in review 45226 is 300
# Number of words in review 45227 is 300
# Number of words in review 45228 is 300
# Number of words in review 45229 is 300
# Number of words in review 45230 is 300
# Number of words in review 45231 is 300
# Number of words in review 45232 is 300
# Number of words in review 45233 is 300
# Number of words in review 45234 is 300
# Number of words in review 45235 is 300
# Number of words in review 45236 is 300
# Number of words in review 45237 is 300
# Number of words in review 45238 is 300
# Number of words in review 45239 is 300
# Number of words in review 45240 is 300
# Number of words in review 45241 is 300
# Number of words in review 45242 is 300
# Number of words in review 45243 is 300
# Number of words in review 45244 is 300
# Number of words in review 45245 is 300
# Number of words in review 45246 is 300
# Number of words in review 45247 is 300
# Number of words in review 45248 is 300
# Number of words in review 45249 is 300
# Number of words in review 45250 is 300
# Number of words in review 45251 is 300
# Number of words in review 45252 is 300
# Number of words in review 45253 is 300
# Number of words in review 45254 is 300
# Number of words in review 45255 is 300
# Number of words in review 45256 is 300
# Number of words in review 45257 is 300
# Number of words in review 45258 is 300
# Number of words in review 45259 is 300
# Number of words in review 45260 is 300
# Number of words in review 45261 is 300
# Number of words in review 45262 is 300
# Number of words in review 45263 is 300
# Number of words in review 45264 is 300
# Number of words in review 45265 is 300
# Number of words in review 45266 is 300
# Number of words in review 45267 is 300
# Number of words in review 45268 is 300
# Number of words in review 45269 is 300
# Number of words in review 45270 is 300
# Number of words in review 45271 is 300
# Number of words in review 45272 is 300
# Number of words in review 45273 is 300
# Number of words in review 45274 is 300
# Number of words in review 45275 is 300
# Number of words in review 45276 is 300
# Number of words in review 45277 is 300
# Number of words in review 45278 is 300
# Number of words in review 45279 is 300
# Number of words in review 45280 is 300
# Number of words in review 45281 is 300
# Number of words in review 45282 is 300
# Number of words in review 45283 is 300
# Number of words in review 45284 is 300
# Number of words in review 45285 is 300
# Number of words in review 45286 is 300
# Number of words in review 45287 is 300
# Number of words in review 45288 is 300
# Number of words in review 45289 is 300
# Number of words in review 45290 is 300
# Number of words in review 45291 is 300
# Number of words in review 45292 is 300
# Number of words in review 45293 is 300
# Number of words in review 45294 is 300
# Number of words in review 45295 is 300
# Number of words in review 45296 is 300
# Number of words in review 45297 is 300
# Number of words in review 45298 is 300
# Number of words in review 45299 is 300
# Number of words in review 45300 is 300
# Number of words in review 45301 is 300
# Number of words in review 45302 is 300
# Number of words in review 45303 is 300
# Number of words in review 45304 is 300
# Number of words in review 45305 is 300
# Number of words in review 45306 is 300
# Number of words in review 45307 is 300
# Number of words in review 45308 is 300
# Number of words in review 45309 is 300
# Number of words in review 45310 is 300
# Number of words in review 45311 is 300
# Number of words in review 45312 is 300
# Number of words in review 45313 is 300
# Number of words in review 45314 is 300
# Number of words in review 45315 is 300
# Number of words in review 45316 is 300
# Number of words in review 45317 is 300
# Number of words in review 45318 is 300
# Number of words in review 45319 is 300
# Number of words in review 45320 is 300
# Number of words in review 45321 is 300
# Number of words in review 45322 is 300
# Number of words in review 45323 is 300
# Number of words in review 45324 is 300
# Number of words in review 45325 is 300
# Number of words in review 45326 is 300
# Number of words in review 45327 is 300
# Number of words in review 45328 is 300
# Number of words in review 45329 is 300
# Number of words in review 45330 is 300
# Number of words in review 45331 is 300
# Number of words in review 45332 is 300
# Number of words in review 45333 is 300
# Number of words in review 45334 is 300
# Number of words in review 45335 is 300
# Number of words in review 45336 is 300
# Number of words in review 45337 is 300
# Number of words in review 45338 is 300
# Number of words in review 45339 is 300
# Number of words in review 45340 is 300
# Number of words in review 45341 is 300
# Number of words in review 45342 is 300
# Number of words in review 45343 is 300
# Number of words in review 45344 is 300
# Number of words in review 45345 is 300
# Number of words in review 45346 is 300
# Number of words in review 45347 is 300
# Number of words in review 45348 is 300
# Number of words in review 45349 is 300
# Number of words in review 45350 is 300
# Number of words in review 45351 is 300
# Number of words in review 45352 is 300
# Number of words in review 45353 is 300
# Number of words in review 45354 is 300
# Number of words in review 45355 is 300
# Number of words in review 45356 is 300
# Number of words in review 45357 is 300
# Number of words in review 45358 is 300
# Number of words in review 45359 is 300
# Number of words in review 45360 is 300
# Number of words in review 45361 is 300
# Number of words in review 45362 is 300
# Number of words in review 45363 is 300
# Number of words in review 45364 is 300
# Number of words in review 45365 is 300
# Number of words in review 45366 is 300
# Number of words in review 45367 is 300
# Number of words in review 45368 is 300
# Number of words in review 45369 is 300
# Number of words in review 45370 is 300
# Number of words in review 45371 is 300
# Number of words in review 45372 is 300
# Number of words in review 45373 is 300
# Number of words in review 45374 is 300
# Number of words in review 45375 is 300
# Number of words in review 45376 is 300
# Number of words in review 45377 is 300
# Number of words in review 45378 is 300
# Number of words in review 45379 is 300
# Number of words in review 45380 is 300
# Number of words in review 45381 is 300
# Number of words in review 45382 is 300
# Number of words in review 45383 is 300
# Number of words in review 45384 is 300
# Number of words in review 45385 is 300
# Number of words in review 45386 is 300
# Number of words in review 45387 is 300
# Number of words in review 45388 is 300
# Number of words in review 45389 is 300
# Number of words in review 45390 is 300
# Number of words in review 45391 is 300
# Number of words in review 45392 is 300
# Number of words in review 45393 is 300
# Number of words in review 45394 is 300
# Number of words in review 45395 is 300
# Number of words in review 45396 is 300
# Number of words in review 45397 is 300
# Number of words in review 45398 is 300
# Number of words in review 45399 is 300
# Number of words in review 45400 is 300
# Number of words in review 45401 is 300
# Number of words in review 45402 is 300
# Number of words in review 45403 is 300
# Number of words in review 45404 is 300
# Number of words in review 45405 is 300
# Number of words in review 45406 is 300
# Number of words in review 45407 is 300
# Number of words in review 45408 is 300
# Number of words in review 45409 is 300
# Number of words in review 45410 is 300
# Number of words in review 45411 is 300
# Number of words in review 45412 is 300
# Number of words in review 45413 is 300
# Number of words in review 45414 is 300
# Number of words in review 45415 is 300
# Number of words in review 45416 is 300
# Number of words in review 45417 is 300
# Number of words in review 45418 is 300
# Number of words in review 45419 is 300
# Number of words in review 45420 is 300
# Number of words in review 45421 is 300
# Number of words in review 45422 is 300
# Number of words in review 45423 is 300
# Number of words in review 45424 is 300
# Number of words in review 45425 is 300
# Number of words in review 45426 is 300
# Number of words in review 45427 is 300
# Number of words in review 45428 is 300
# Number of words in review 45429 is 300
# Number of words in review 45430 is 300
# Number of words in review 45431 is 300
# Number of words in review 45432 is 300
# Number of words in review 45433 is 300
# Number of words in review 45434 is 300
# Number of words in review 45435 is 300
# Number of words in review 45436 is 300
# Number of words in review 45437 is 300
# Number of words in review 45438 is 300
# Number of words in review 45439 is 300
# Number of words in review 45440 is 300
# Number of words in review 45441 is 300
# Number of words in review 45442 is 300
# Number of words in review 45443 is 300
# Number of words in review 45444 is 300
# Number of words in review 45445 is 300
# Number of words in review 45446 is 300
# Number of words in review 45447 is 300
# Number of words in review 45448 is 300
# Number of words in review 45449 is 300
# Number of words in review 45450 is 300
# Number of words in review 45451 is 300
# Number of words in review 45452 is 300
# Number of words in review 45453 is 300
# Number of words in review 45454 is 300
# Number of words in review 45455 is 300
# Number of words in review 45456 is 300
# Number of words in review 45457 is 300
# Number of words in review 45458 is 300
# Number of words in review 45459 is 300
# Number of words in review 45460 is 300
# Number of words in review 45461 is 300
# Number of words in review 45462 is 300
# Number of words in review 45463 is 300
# Number of words in review 45464 is 300
# Number of words in review 45465 is 300
# Number of words in review 45466 is 300
# Number of words in review 45467 is 300
# Number of words in review 45468 is 300
# Number of words in review 45469 is 300
# Number of words in review 45470 is 300
# Number of words in review 45471 is 300
# Number of words in review 45472 is 300
# Number of words in review 45473 is 300
# Number of words in review 45474 is 300
# Number of words in review 45475 is 300
# Number of words in review 45476 is 300
# Number of words in review 45477 is 300
# Number of words in review 45478 is 300
# Number of words in review 45479 is 300
# Number of words in review 45480 is 300
# Number of words in review 45481 is 300
# Number of words in review 45482 is 300
# Number of words in review 45483 is 300
# Number of words in review 45484 is 300
# Number of words in review 45485 is 300
# Number of words in review 45486 is 300
# Number of words in review 45487 is 300
# Number of words in review 45488 is 300
# Number of words in review 45489 is 300
# Number of words in review 45490 is 300
# Number of words in review 45491 is 300
# Number of words in review 45492 is 300
# Number of words in review 45493 is 300
# Number of words in review 45494 is 300
# Number of words in review 45495 is 300
# Number of words in review 45496 is 300
# Number of words in review 45497 is 300
# Number of words in review 45498 is 300
# Number of words in review 45499 is 300
# Number of words in review 45500 is 300
# Number of words in review 45501 is 300
# Number of words in review 45502 is 300
# Number of words in review 45503 is 300
# Number of words in review 45504 is 300
# Number of words in review 45505 is 300
# Number of words in review 45506 is 300
# Number of words in review 45507 is 300
# Number of words in review 45508 is 300
# Number of words in review 45509 is 300
# Number of words in review 45510 is 300
# Number of words in review 45511 is 300
# Number of words in review 45512 is 300
# Number of words in review 45513 is 300
# Number of words in review 45514 is 300
# Number of words in review 45515 is 300
# Number of words in review 45516 is 300
# Number of words in review 45517 is 300
# Number of words in review 45518 is 300
# Number of words in review 45519 is 300
# Number of words in review 45520 is 300
# Number of words in review 45521 is 300
# Number of words in review 45522 is 300
# Number of words in review 45523 is 300
# Number of words in review 45524 is 300
# Number of words in review 45525 is 300
# Number of words in review 45526 is 300
# Number of words in review 45527 is 300
# Number of words in review 45528 is 300
# Number of words in review 45529 is 300
# Number of words in review 45530 is 300
# Number of words in review 45531 is 300
# Number of words in review 45532 is 300
# Number of words in review 45533 is 300
# Number of words in review 45534 is 300
# Number of words in review 45535 is 300
# Number of words in review 45536 is 300
# Number of words in review 45537 is 300
# Number of words in review 45538 is 300
# Number of words in review 45539 is 300
# Number of words in review 45540 is 300
# Number of words in review 45541 is 300
# Number of words in review 45542 is 300
# Number of words in review 45543 is 300
# Number of words in review 45544 is 300
# Number of words in review 45545 is 300
# Number of words in review 45546 is 300
# Number of words in review 45547 is 300
# Number of words in review 45548 is 300
# Number of words in review 45549 is 300
# Number of words in review 45550 is 300
# Number of words in review 45551 is 300
# Number of words in review 45552 is 300
# Number of words in review 45553 is 300
# Number of words in review 45554 is 300
# Number of words in review 45555 is 300
# Number of words in review 45556 is 300
# Number of words in review 45557 is 300
# Number of words in review 45558 is 300
# Number of words in review 45559 is 300
# Number of words in review 45560 is 300
# Number of words in review 45561 is 300
# Number of words in review 45562 is 300
# Number of words in review 45563 is 300
# Number of words in review 45564 is 300
# Number of words in review 45565 is 300
# Number of words in review 45566 is 300
# Number of words in review 45567 is 300
# Number of words in review 45568 is 300
# Number of words in review 45569 is 300
# Number of words in review 45570 is 300
# Number of words in review 45571 is 300
# Number of words in review 45572 is 300
# Number of words in review 45573 is 300
# Number of words in review 45574 is 300
# Number of words in review 45575 is 300
# Number of words in review 45576 is 300
# Number of words in review 45577 is 300
# Number of words in review 45578 is 300
# Number of words in review 45579 is 300
# Number of words in review 45580 is 300
# Number of words in review 45581 is 300
# Number of words in review 45582 is 300
# Number of words in review 45583 is 300
# Number of words in review 45584 is 300
# Number of words in review 45585 is 300
# Number of words in review 45586 is 300
# Number of words in review 45587 is 300
# Number of words in review 45588 is 300
# Number of words in review 45589 is 300
# Number of words in review 45590 is 300
# Number of words in review 45591 is 300
# Number of words in review 45592 is 300
# Number of words in review 45593 is 300
# Number of words in review 45594 is 300
# Number of words in review 45595 is 300
# Number of words in review 45596 is 300
# Number of words in review 45597 is 300
# Number of words in review 45598 is 300
# Number of words in review 45599 is 300
# Number of words in review 45600 is 300
# Number of words in review 45601 is 300
# Number of words in review 45602 is 300
# Number of words in review 45603 is 300
# Number of words in review 45604 is 300
# Number of words in review 45605 is 300
# Number of words in review 45606 is 300
# Number of words in review 45607 is 300
# Number of words in review 45608 is 300
# Number of words in review 45609 is 300
# Number of words in review 45610 is 300
# Number of words in review 45611 is 300
# Number of words in review 45612 is 300
# Number of words in review 45613 is 300
# Number of words in review 45614 is 300
# Number of words in review 45615 is 300
# Number of words in review 45616 is 300
# Number of words in review 45617 is 300
# Number of words in review 45618 is 300
# Number of words in review 45619 is 300
# Number of words in review 45620 is 300
# Number of words in review 45621 is 300
# Number of words in review 45622 is 300
# Number of words in review 45623 is 300
# Number of words in review 45624 is 300
# Number of words in review 45625 is 300
# Number of words in review 45626 is 300
# Number of words in review 45627 is 300
# Number of words in review 45628 is 300
# Number of words in review 45629 is 300
# Number of words in review 45630 is 300
# Number of words in review 45631 is 300
# Number of words in review 45632 is 300
# Number of words in review 45633 is 300
# Number of words in review 45634 is 300
# Number of words in review 45635 is 300
# Number of words in review 45636 is 300
# Number of words in review 45637 is 300
# Number of words in review 45638 is 300
# Number of words in review 45639 is 300
# Number of words in review 45640 is 300
# Number of words in review 45641 is 300
# Number of words in review 45642 is 300
# Number of words in review 45643 is 300
# Number of words in review 45644 is 300
# Number of words in review 45645 is 300
# Number of words in review 45646 is 300
# Number of words in review 45647 is 300
# Number of words in review 45648 is 300
# Number of words in review 45649 is 300
# Number of words in review 45650 is 300
# Number of words in review 45651 is 300
# Number of words in review 45652 is 300
# Number of words in review 45653 is 300
# Number of words in review 45654 is 300
# Number of words in review 45655 is 300
# Number of words in review 45656 is 300
# Number of words in review 45657 is 300
# Number of words in review 45658 is 300
# Number of words in review 45659 is 300
# Number of words in review 45660 is 300
# Number of words in review 45661 is 300
# Number of words in review 45662 is 300
# Number of words in review 45663 is 300
# Number of words in review 45664 is 300
# Number of words in review 45665 is 300
# Number of words in review 45666 is 300
# Number of words in review 45667 is 300
# Number of words in review 45668 is 300
# Number of words in review 45669 is 300
# Number of words in review 45670 is 300
# Number of words in review 45671 is 300
# Number of words in review 45672 is 300
# Number of words in review 45673 is 300
# Number of words in review 45674 is 300
# Number of words in review 45675 is 300
# Number of words in review 45676 is 300
# Number of words in review 45677 is 300
# Number of words in review 45678 is 300
# Number of words in review 45679 is 300
# Number of words in review 45680 is 300
# Number of words in review 45681 is 300
# Number of words in review 45682 is 300
# Number of words in review 45683 is 300
# Number of words in review 45684 is 300
# Number of words in review 45685 is 300
# Number of words in review 45686 is 300
# Number of words in review 45687 is 300
# Number of words in review 45688 is 300
# Number of words in review 45689 is 300
# Number of words in review 45690 is 300
# Number of words in review 45691 is 300
# Number of words in review 45692 is 300
# Number of words in review 45693 is 300
# Number of words in review 45694 is 300
# Number of words in review 45695 is 300
# Number of words in review 45696 is 300
# Number of words in review 45697 is 300
# Number of words in review 45698 is 300
# Number of words in review 45699 is 300
# Number of words in review 45700 is 300
# Number of words in review 45701 is 300
# Number of words in review 45702 is 300
# Number of words in review 45703 is 300
# Number of words in review 45704 is 300
# Number of words in review 45705 is 300
# Number of words in review 45706 is 300
# Number of words in review 45707 is 300
# Number of words in review 45708 is 300
# Number of words in review 45709 is 300
# Number of words in review 45710 is 300
# Number of words in review 45711 is 300
# Number of words in review 45712 is 300
# Number of words in review 45713 is 300
# Number of words in review 45714 is 300
# Number of words in review 45715 is 300
# Number of words in review 45716 is 300
# Number of words in review 45717 is 300
# Number of words in review 45718 is 300
# Number of words in review 45719 is 300
# Number of words in review 45720 is 300
# Number of words in review 45721 is 300
# Number of words in review 45722 is 300
# Number of words in review 45723 is 300
# Number of words in review 45724 is 300
# Number of words in review 45725 is 300
# Number of words in review 45726 is 300
# Number of words in review 45727 is 300
# Number of words in review 45728 is 300
# Number of words in review 45729 is 300
# Number of words in review 45730 is 300
# Number of words in review 45731 is 300
# Number of words in review 45732 is 300
# Number of words in review 45733 is 300
# Number of words in review 45734 is 300
# Number of words in review 45735 is 300
# Number of words in review 45736 is 300
# Number of words in review 45737 is 300
# Number of words in review 45738 is 300
# Number of words in review 45739 is 300
# Number of words in review 45740 is 300
# Number of words in review 45741 is 300
# Number of words in review 45742 is 300
# Number of words in review 45743 is 300
# Number of words in review 45744 is 300
# Number of words in review 45745 is 300
# Number of words in review 45746 is 300
# Number of words in review 45747 is 300
# Number of words in review 45748 is 300
# Number of words in review 45749 is 300
# Number of words in review 45750 is 300
# Number of words in review 45751 is 300
# Number of words in review 45752 is 300
# Number of words in review 45753 is 300
# Number of words in review 45754 is 300
# Number of words in review 45755 is 300
# Number of words in review 45756 is 300
# Number of words in review 45757 is 300
# Number of words in review 45758 is 300
# Number of words in review 45759 is 300
# Number of words in review 45760 is 300
# Number of words in review 45761 is 300
# Number of words in review 45762 is 300
# Number of words in review 45763 is 300
# Number of words in review 45764 is 300
# Number of words in review 45765 is 300
# Number of words in review 45766 is 300
# Number of words in review 45767 is 300
# Number of words in review 45768 is 300
# Number of words in review 45769 is 300
# Number of words in review 45770 is 300
# Number of words in review 45771 is 300
# Number of words in review 45772 is 300
# Number of words in review 45773 is 300
# Number of words in review 45774 is 300
# Number of words in review 45775 is 300
# Number of words in review 45776 is 300
# Number of words in review 45777 is 300
# Number of words in review 45778 is 300
# Number of words in review 45779 is 300
# Number of words in review 45780 is 300
# Number of words in review 45781 is 300
# Number of words in review 45782 is 300
# Number of words in review 45783 is 300
# Number of words in review 45784 is 300
# Number of words in review 45785 is 300
# Number of words in review 45786 is 300
# Number of words in review 45787 is 300
# Number of words in review 45788 is 300
# Number of words in review 45789 is 300
# Number of words in review 45790 is 300
# Number of words in review 45791 is 300
# Number of words in review 45792 is 300
# Number of words in review 45793 is 300
# Number of words in review 45794 is 300
# Number of words in review 45795 is 300
# Number of words in review 45796 is 300
# Number of words in review 45797 is 300
# Number of words in review 45798 is 300
# Number of words in review 45799 is 300
# Number of words in review 45800 is 300
# Number of words in review 45801 is 300
# Number of words in review 45802 is 300
# Number of words in review 45803 is 300
# Number of words in review 45804 is 300
# Number of words in review 45805 is 300
# Number of words in review 45806 is 300
# Number of words in review 45807 is 300
# Number of words in review 45808 is 300
# Number of words in review 45809 is 300
# Number of words in review 45810 is 300
# Number of words in review 45811 is 300
# Number of words in review 45812 is 300
# Number of words in review 45813 is 300
# Number of words in review 45814 is 300
# Number of words in review 45815 is 300
# Number of words in review 45816 is 300
# Number of words in review 45817 is 300
# Number of words in review 45818 is 300
# Number of words in review 45819 is 300
# Number of words in review 45820 is 300
# Number of words in review 45821 is 300
# Number of words in review 45822 is 300
# Number of words in review 45823 is 300
# Number of words in review 45824 is 300
# Number of words in review 45825 is 300
# Number of words in review 45826 is 300
# Number of words in review 45827 is 300
# Number of words in review 45828 is 300
# Number of words in review 45829 is 300
# Number of words in review 45830 is 300
# Number of words in review 45831 is 300
# Number of words in review 45832 is 300
# Number of words in review 45833 is 300
# Number of words in review 45834 is 300
# Number of words in review 45835 is 300
# Number of words in review 45836 is 300
# Number of words in review 45837 is 300
# Number of words in review 45838 is 300
# Number of words in review 45839 is 300
# Number of words in review 45840 is 300
# Number of words in review 45841 is 300
# Number of words in review 45842 is 300
# Number of words in review 45843 is 300
# Number of words in review 45844 is 300
# Number of words in review 45845 is 300
# Number of words in review 45846 is 300
# Number of words in review 45847 is 300
# Number of words in review 45848 is 300
# Number of words in review 45849 is 300
# Number of words in review 45850 is 300
# Number of words in review 45851 is 300
# Number of words in review 45852 is 300
# Number of words in review 45853 is 300
# Number of words in review 45854 is 300
# Number of words in review 45855 is 300
# Number of words in review 45856 is 300
# Number of words in review 45857 is 300
# Number of words in review 45858 is 300
# Number of words in review 45859 is 300
# Number of words in review 45860 is 300
# Number of words in review 45861 is 300
# Number of words in review 45862 is 300
# Number of words in review 45863 is 300
# Number of words in review 45864 is 300
# Number of words in review 45865 is 300
# Number of words in review 45866 is 300
# Number of words in review 45867 is 300
# Number of words in review 45868 is 300
# Number of words in review 45869 is 300
# Number of words in review 45870 is 300
# Number of words in review 45871 is 300
# Number of words in review 45872 is 300
# Number of words in review 45873 is 300
# Number of words in review 45874 is 300
# Number of words in review 45875 is 300
# Number of words in review 45876 is 300
# Number of words in review 45877 is 300
# Number of words in review 45878 is 300
# Number of words in review 45879 is 300
# Number of words in review 45880 is 300
# Number of words in review 45881 is 300
# Number of words in review 45882 is 300
# Number of words in review 45883 is 300
# Number of words in review 45884 is 300
# Number of words in review 45885 is 300
# Number of words in review 45886 is 300
# Number of words in review 45887 is 300
# Number of words in review 45888 is 300
# Number of words in review 45889 is 300
# Number of words in review 45890 is 300
# Number of words in review 45891 is 300
# Number of words in review 45892 is 300
# Number of words in review 45893 is 300
# Number of words in review 45894 is 300
# Number of words in review 45895 is 300
# Number of words in review 45896 is 300
# Number of words in review 45897 is 300
# Number of words in review 45898 is 300
# Number of words in review 45899 is 300
# Number of words in review 45900 is 300
# Number of words in review 45901 is 300
# Number of words in review 45902 is 300
# Number of words in review 45903 is 300
# Number of words in review 45904 is 300
# Number of words in review 45905 is 300
# Number of words in review 45906 is 300
# Number of words in review 45907 is 300
# Number of words in review 45908 is 300
# Number of words in review 45909 is 300
# Number of words in review 45910 is 300
# Number of words in review 45911 is 300
# Number of words in review 45912 is 300
# Number of words in review 45913 is 300
# Number of words in review 45914 is 300
# Number of words in review 45915 is 300
# Number of words in review 45916 is 300
# Number of words in review 45917 is 300
# Number of words in review 45918 is 300
# Number of words in review 45919 is 300
# Number of words in review 45920 is 300
# Number of words in review 45921 is 300
# Number of words in review 45922 is 300
# Number of words in review 45923 is 300
# Number of words in review 45924 is 300
# Number of words in review 45925 is 300
# Number of words in review 45926 is 300
# Number of words in review 45927 is 300
# Number of words in review 45928 is 300
# Number of words in review 45929 is 300
# Number of words in review 45930 is 300
# Number of words in review 45931 is 300
# Number of words in review 45932 is 300
# Number of words in review 45933 is 300
# Number of words in review 45934 is 300
# Number of words in review 45935 is 300
# Number of words in review 45936 is 300
# Number of words in review 45937 is 300
# Number of words in review 45938 is 300
# Number of words in review 45939 is 300
# Number of words in review 45940 is 300
# Number of words in review 45941 is 300
# Number of words in review 45942 is 300
# Number of words in review 45943 is 300
# Number of words in review 45944 is 300
# Number of words in review 45945 is 300
# Number of words in review 45946 is 300
# Number of words in review 45947 is 300
# Number of words in review 45948 is 300
# Number of words in review 45949 is 300
# Number of words in review 45950 is 300
# Number of words in review 45951 is 300
# Number of words in review 45952 is 300
# Number of words in review 45953 is 300
# Number of words in review 45954 is 300
# Number of words in review 45955 is 300
# Number of words in review 45956 is 300
# Number of words in review 45957 is 300
# Number of words in review 45958 is 300
# Number of words in review 45959 is 300
# Number of words in review 45960 is 300
# Number of words in review 45961 is 300
# Number of words in review 45962 is 300
# Number of words in review 45963 is 300
# Number of words in review 45964 is 300
# Number of words in review 45965 is 300
# Number of words in review 45966 is 300
# Number of words in review 45967 is 300
# Number of words in review 45968 is 300
# Number of words in review 45969 is 300
# Number of words in review 45970 is 300
# Number of words in review 45971 is 300
# Number of words in review 45972 is 300
# Number of words in review 45973 is 300
# Number of words in review 45974 is 300
# Number of words in review 45975 is 300
# Number of words in review 45976 is 300
# Number of words in review 45977 is 300
# Number of words in review 45978 is 300
# Number of words in review 45979 is 300
# Number of words in review 45980 is 300
# Number of words in review 45981 is 300
# Number of words in review 45982 is 300
# Number of words in review 45983 is 300
# Number of words in review 45984 is 300
# Number of words in review 45985 is 300
# Number of words in review 45986 is 300
# Number of words in review 45987 is 300
# Number of words in review 45988 is 300
# Number of words in review 45989 is 300
# Number of words in review 45990 is 300
# Number of words in review 45991 is 300
# Number of words in review 45992 is 300
# Number of words in review 45993 is 300
# Number of words in review 45994 is 300
# Number of words in review 45995 is 300
# Number of words in review 45996 is 300
# Number of words in review 45997 is 300
# Number of words in review 45998 is 300
# Number of words in review 45999 is 300
# Number of words in review 46000 is 300
# Number of words in review 46001 is 300
# Number of words in review 46002 is 300
# Number of words in review 46003 is 300
# Number of words in review 46004 is 300
# Number of words in review 46005 is 300
# Number of words in review 46006 is 300
# Number of words in review 46007 is 300
# Number of words in review 46008 is 300
# Number of words in review 46009 is 300
# Number of words in review 46010 is 300
# Number of words in review 46011 is 300
# Number of words in review 46012 is 300
# Number of words in review 46013 is 300
# Number of words in review 46014 is 300
# Number of words in review 46015 is 300
# Number of words in review 46016 is 300
# Number of words in review 46017 is 300
# Number of words in review 46018 is 300
# Number of words in review 46019 is 300
# Number of words in review 46020 is 300
# Number of words in review 46021 is 300
# Number of words in review 46022 is 300
# Number of words in review 46023 is 300
# Number of words in review 46024 is 300
# Number of words in review 46025 is 300
# Number of words in review 46026 is 300
# Number of words in review 46027 is 300
# Number of words in review 46028 is 300
# Number of words in review 46029 is 300
# Number of words in review 46030 is 300
# Number of words in review 46031 is 300
# Number of words in review 46032 is 300
# Number of words in review 46033 is 300
# Number of words in review 46034 is 300
# Number of words in review 46035 is 300
# Number of words in review 46036 is 300
# Number of words in review 46037 is 300
# Number of words in review 46038 is 300
# Number of words in review 46039 is 300
# Number of words in review 46040 is 300
# Number of words in review 46041 is 300
# Number of words in review 46042 is 300
# Number of words in review 46043 is 300
# Number of words in review 46044 is 300
# Number of words in review 46045 is 300
# Number of words in review 46046 is 300
# Number of words in review 46047 is 300
# Number of words in review 46048 is 300
# Number of words in review 46049 is 300
# Number of words in review 46050 is 300
# Number of words in review 46051 is 300
# Number of words in review 46052 is 300
# Number of words in review 46053 is 300
# Number of words in review 46054 is 300
# Number of words in review 46055 is 300
# Number of words in review 46056 is 300
# Number of words in review 46057 is 300
# Number of words in review 46058 is 300
# Number of words in review 46059 is 300
# Number of words in review 46060 is 300
# Number of words in review 46061 is 300
# Number of words in review 46062 is 300
# Number of words in review 46063 is 300
# Number of words in review 46064 is 300
# Number of words in review 46065 is 300
# Number of words in review 46066 is 300
# Number of words in review 46067 is 300
# Number of words in review 46068 is 300
# Number of words in review 46069 is 300
# Number of words in review 46070 is 300
# Number of words in review 46071 is 300
# Number of words in review 46072 is 300
# Number of words in review 46073 is 300
# Number of words in review 46074 is 300
# Number of words in review 46075 is 300
# Number of words in review 46076 is 300
# Number of words in review 46077 is 300
# Number of words in review 46078 is 300
# Number of words in review 46079 is 300
# Number of words in review 46080 is 300
# Number of words in review 46081 is 300
# Number of words in review 46082 is 300
# Number of words in review 46083 is 300
# Number of words in review 46084 is 300
# Number of words in review 46085 is 300
# Number of words in review 46086 is 300
# Number of words in review 46087 is 300
# Number of words in review 46088 is 300
# Number of words in review 46089 is 300
# Number of words in review 46090 is 300
# Number of words in review 46091 is 300
# Number of words in review 46092 is 300
# Number of words in review 46093 is 300
# Number of words in review 46094 is 300
# Number of words in review 46095 is 300
# Number of words in review 46096 is 300
# Number of words in review 46097 is 300
# Number of words in review 46098 is 300
# Number of words in review 46099 is 300
# Number of words in review 46100 is 300
# Number of words in review 46101 is 300
# Number of words in review 46102 is 300
# Number of words in review 46103 is 300
# Number of words in review 46104 is 300
# Number of words in review 46105 is 300
# Number of words in review 46106 is 300
# Number of words in review 46107 is 300
# Number of words in review 46108 is 300
# Number of words in review 46109 is 300
# Number of words in review 46110 is 300
# Number of words in review 46111 is 300
# Number of words in review 46112 is 300
# Number of words in review 46113 is 300
# Number of words in review 46114 is 300
# Number of words in review 46115 is 300
# Number of words in review 46116 is 300
# Number of words in review 46117 is 300
# Number of words in review 46118 is 300
# Number of words in review 46119 is 300
# Number of words in review 46120 is 300
# Number of words in review 46121 is 300
# Number of words in review 46122 is 300
# Number of words in review 46123 is 300
# Number of words in review 46124 is 300
# Number of words in review 46125 is 300
# Number of words in review 46126 is 300
# Number of words in review 46127 is 300
# Number of words in review 46128 is 300
# Number of words in review 46129 is 300
# Number of words in review 46130 is 300
# Number of words in review 46131 is 300
# Number of words in review 46132 is 300
# Number of words in review 46133 is 300
# Number of words in review 46134 is 300
# Number of words in review 46135 is 300
# Number of words in review 46136 is 300
# Number of words in review 46137 is 300
# Number of words in review 46138 is 300
# Number of words in review 46139 is 300
# Number of words in review 46140 is 300
# Number of words in review 46141 is 300
# Number of words in review 46142 is 300
# Number of words in review 46143 is 300
# Number of words in review 46144 is 300
# Number of words in review 46145 is 300
# Number of words in review 46146 is 300
# Number of words in review 46147 is 300
# Number of words in review 46148 is 300
# Number of words in review 46149 is 300
# Number of words in review 46150 is 300
# Number of words in review 46151 is 300
# Number of words in review 46152 is 300
# Number of words in review 46153 is 300
# Number of words in review 46154 is 300
# Number of words in review 46155 is 300
# Number of words in review 46156 is 300
# Number of words in review 46157 is 300
# Number of words in review 46158 is 300
# Number of words in review 46159 is 300
# Number of words in review 46160 is 300
# Number of words in review 46161 is 300
# Number of words in review 46162 is 300
# Number of words in review 46163 is 300
# Number of words in review 46164 is 300
# Number of words in review 46165 is 300
# Number of words in review 46166 is 300
# Number of words in review 46167 is 300
# Number of words in review 46168 is 300
# Number of words in review 46169 is 300
# Number of words in review 46170 is 300
# Number of words in review 46171 is 300
# Number of words in review 46172 is 300
# Number of words in review 46173 is 300
# Number of words in review 46174 is 300
# Number of words in review 46175 is 300
# Number of words in review 46176 is 300
# Number of words in review 46177 is 300
# Number of words in review 46178 is 300
# Number of words in review 46179 is 300
# Number of words in review 46180 is 300
# Number of words in review 46181 is 300
# Number of words in review 46182 is 300
# Number of words in review 46183 is 300
# Number of words in review 46184 is 300
# Number of words in review 46185 is 300
# Number of words in review 46186 is 300
# Number of words in review 46187 is 300
# Number of words in review 46188 is 300
# Number of words in review 46189 is 300
# Number of words in review 46190 is 300
# Number of words in review 46191 is 300
# Number of words in review 46192 is 300
# Number of words in review 46193 is 300
# Number of words in review 46194 is 300
# Number of words in review 46195 is 300
# Number of words in review 46196 is 300
# Number of words in review 46197 is 300
# Number of words in review 46198 is 300
# Number of words in review 46199 is 300
# Number of words in review 46200 is 300
# Number of words in review 46201 is 300
# Number of words in review 46202 is 300
# Number of words in review 46203 is 300
# Number of words in review 46204 is 300
# Number of words in review 46205 is 300
# Number of words in review 46206 is 300
# Number of words in review 46207 is 300
# Number of words in review 46208 is 300
# Number of words in review 46209 is 300
# Number of words in review 46210 is 300
# Number of words in review 46211 is 300
# Number of words in review 46212 is 300
# Number of words in review 46213 is 300
# Number of words in review 46214 is 300
# Number of words in review 46215 is 300
# Number of words in review 46216 is 300
# Number of words in review 46217 is 300
# Number of words in review 46218 is 300
# Number of words in review 46219 is 300
# Number of words in review 46220 is 300
# Number of words in review 46221 is 300
# Number of words in review 46222 is 300
# Number of words in review 46223 is 300
# Number of words in review 46224 is 300
# Number of words in review 46225 is 300
# Number of words in review 46226 is 300
# Number of words in review 46227 is 300
# Number of words in review 46228 is 300
# Number of words in review 46229 is 300
# ...
# Number of words in review 49591 is 300
# Number of words in review 49592 is 300
# Number of words in review 49593 is 300
# Number of words in review 49594 is 300
# Number of words in review 49595 is 300
# Number of words in review 49596 is 300
# Number of words in review 49597 is 300
# Number of words in review 49598 is 300
# Number of words in review 49599 is 300
# Number of words in review 49600 is 300
# Number of words in review 49601 is 300
# Number of words in review 49602 is 300
# Number of words in review 49603 is 300
# Number of words in review 49604 is 300
# Number of words in review 49605 is 300
# Number of words in review 49606 is 300
# Number of words in review 49607 is 300
# Number of words in review 49608 is 300
# Number of words in review 49609 is 300
# Number of words in review 49610 is 300
# Number of words in review 49611 is 300
# Number of words in review 49612 is 300
# Number of words in review 49613 is 300
# Number of words in review 49614 is 300
# Number of words in review 49615 is 300
# Number of words in review 49616 is 300
# Number of words in review 49617 is 300
# Number of words in review 49618 is 300
# Number of words in review 49619 is 300
# Number of words in review 49620 is 300
# Number of words in review 49621 is 300
# Number of words in review 49622 is 300
# Number of words in review 49623 is 300
# Number of words in review 49624 is 300
# Number of words in review 49625 is 300
# Number of words in review 49626 is 300
# Number of words in review 49627 is 300
# Number of words in review 49628 is 300
# Number of words in review 49629 is 300
# Number of words in review 49630 is 300
# Number of words in review 49631 is 300
# Number of words in review 49632 is 300
# Number of words in review 49633 is 300
# Number of words in review 49634 is 300
# Number of words in review 49635 is 300
# Number of words in review 49636 is 300
# Number of words in review 49637 is 300
# Number of words in review 49638 is 300
# Number of words in review 49639 is 300
# Number of words in review 49640 is 300
# Number of words in review 49641 is 300
# Number of words in review 49642 is 300
# Number of words in review 49643 is 300
# Number of words in review 49644 is 300
# Number of words in review 49645 is 300
# Number of words in review 49646 is 300
# Number of words in review 49647 is 300
# Number of words in review 49648 is 300
# Number of words in review 49649 is 300
# Number of words in review 49650 is 300
# Number of words in review 49651 is 300
# Number of words in review 49652 is 300
# Number of words in review 49653 is 300
# Number of words in review 49654 is 300
# Number of words in review 49655 is 300
# Number of words in review 49656 is 300
# Number of words in review 49657 is 300
# Number of words in review 49658 is 300
# Number of words in review 49659 is 300
# Number of words in review 49660 is 300
# Number of words in review 49661 is 300
# Number of words in review 49662 is 300
# Number of words in review 49663 is 300
# Number of words in review 49664 is 300
# Number of words in review 49665 is 300
# Number of words in review 49666 is 300
# Number of words in review 49667 is 300
# Number of words in review 49668 is 300
# Number of words in review 49669 is 300
# Number of words in review 49670 is 300
# Number of words in review 49671 is 300
# Number of words in review 49672 is 300
# Number of words in review 49673 is 300
# Number of words in review 49674 is 300
# Number of words in review 49675 is 300
# Number of words in review 49676 is 300
# Number of words in review 49677 is 300
# Number of words in review 49678 is 300
# Number of words in review 49679 is 300
# Number of words in review 49680 is 300
# Number of words in review 49681 is 300
# Number of words in review 49682 is 300
# Number of words in review 49683 is 300
# Number of words in review 49684 is 300
# Number of words in review 49685 is 300
# Number of words in review 49686 is 300
# Number of words in review 49687 is 300
# Number of words in review 49688 is 300
# Number of words in review 49689 is 300
# Number of words in review 49690 is 300
# Number of words in review 49691 is 300
# Number of words in review 49692 is 300
# Number of words in review 49693 is 300
# Number of words in review 49694 is 300
# Number of words in review 49695 is 300
# Number of words in review 49696 is 300
# Number of words in review 49697 is 300
# Number of words in review 49698 is 300
# Number of words in review 49699 is 300
# Number of words in review 49700 is 300
# Number of words in review 49701 is 300
# Number of words in review 49702 is 300
# Number of words in review 49703 is 300
# Number of words in review 49704 is 300
# Number of words in review 49705 is 300
# Number of words in review 49706 is 300
# Number of words in review 49707 is 300
# Number of words in review 49708 is 300
# Number of words in review 49709 is 300
# Number of words in review 49710 is 300
# Number of words in review 49711 is 300
# Number of words in review 49712 is 300
# Number of words in review 49713 is 300
# Number of words in review 49714 is 300
# Number of words in review 49715 is 300
# Number of words in review 49716 is 300
# Number of words in review 49717 is 300
# Number of words in review 49718 is 300
# Number of words in review 49719 is 300
# Number of words in review 49720 is 300
# Number of words in review 49721 is 300
# Number of words in review 49722 is 300
# Number of words in review 49723 is 300
# Number of words in review 49724 is 300
# Number of words in review 49725 is 300
# Number of words in review 49726 is 300
# Number of words in review 49727 is 300
# Number of words in review 49728 is 300
# Number of words in review 49729 is 300
# Number of words in review 49730 is 300
# Number of words in review 49731 is 300
# Number of words in review 49732 is 300
# Number of words in review 49733 is 300
# Number of words in review 49734 is 300
# Number of words in review 49735 is 300
# Number of words in review 49736 is 300
# Number of words in review 49737 is 300
# Number of words in review 49738 is 300
# Number of words in review 49739 is 300
# Number of words in review 49740 is 300
# Number of words in review 49741 is 300
# Number of words in review 49742 is 300
# Number of words in review 49743 is 300
# Number of words in review 49744 is 300
# Number of words in review 49745 is 300
# Number of words in review 49746 is 300
# Number of words in review 49747 is 300
# Number of words in review 49748 is 300
# Number of words in review 49749 is 300
# Number of words in review 49750 is 300
# Number of words in review 49751 is 300
# Number of words in review 49752 is 300
# Number of words in review 49753 is 300
# Number of words in review 49754 is 300
# Number of words in review 49755 is 300
# Number of words in review 49756 is 300
# Number of words in review 49757 is 300
# Number of words in review 49758 is 300
# Number of words in review 49759 is 300
# Number of words in review 49760 is 300
# Number of words in review 49761 is 300
# Number of words in review 49762 is 300
# Number of words in review 49763 is 300
# Number of words in review 49764 is 300
# Number of words in review 49765 is 300
# Number of words in review 49766 is 300
# Number of words in review 49767 is 300
# Number of words in review 49768 is 300
# Number of words in review 49769 is 300
# Number of words in review 49770 is 300
# Number of words in review 49771 is 300
# Number of words in review 49772 is 300
# Number of words in review 49773 is 300
# Number of words in review 49774 is 300
# Number of words in review 49775 is 300
# Number of words in review 49776 is 300
# Number of words in review 49777 is 300
# Number of words in review 49778 is 300
# Number of words in review 49779 is 300
# Number of words in review 49780 is 300
# Number of words in review 49781 is 300
# Number of words in review 49782 is 300
# Number of words in review 49783 is 300
# Number of words in review 49784 is 300
# Number of words in review 49785 is 300
# Number of words in review 49786 is 300
# Number of words in review 49787 is 300
# Number of words in review 49788 is 300
# Number of words in review 49789 is 300
# Number of words in review 49790 is 300
# Number of words in review 49791 is 300
# Number of words in review 49792 is 300
# Number of words in review 49793 is 300
# Number of words in review 49794 is 300
# Number of words in review 49795 is 300
# Number of words in review 49796 is 300
# Number of words in review 49797 is 300
# Number of words in review 49798 is 300
# Number of words in review 49799 is 300
# Number of words in review 49800 is 300
# Number of words in review 49801 is 300
# Number of words in review 49802 is 300
# Number of words in review 49803 is 300
# Number of words in review 49804 is 300
# Number of words in review 49805 is 300
# Number of words in review 49806 is 300
# Number of words in review 49807 is 300
# Number of words in review 49808 is 300
# Number of words in review 49809 is 300
# Number of words in review 49810 is 300
# Number of words in review 49811 is 300
# Number of words in review 49812 is 300
# Number of words in review 49813 is 300
# Number of words in review 49814 is 300
# Number of words in review 49815 is 300
# Number of words in review 49816 is 300
# Number of words in review 49817 is 300
# Number of words in review 49818 is 300
# Number of words in review 49819 is 300
# Number of words in review 49820 is 300
# Number of words in review 49821 is 300
# Number of words in review 49822 is 300
# Number of words in review 49823 is 300
# Number of words in review 49824 is 300
# Number of words in review 49825 is 300
# Number of words in review 49826 is 300
# Number of words in review 49827 is 300
# Number of words in review 49828 is 300
# Number of words in review 49829 is 300
# Number of words in review 49830 is 300
# Number of words in review 49831 is 300
# Number of words in review 49832 is 300
# Number of words in review 49833 is 300
# Number of words in review 49834 is 300
# Number of words in review 49835 is 300
# Number of words in review 49836 is 300
# Number of words in review 49837 is 300
# Number of words in review 49838 is 300
# Number of words in review 49839 is 300
# Number of words in review 49840 is 300
# Number of words in review 49841 is 300
# Number of words in review 49842 is 300
# Number of words in review 49843 is 300
# Number of words in review 49844 is 300
# Number of words in review 49845 is 300
# Number of words in review 49846 is 300
# Number of words in review 49847 is 300
# Number of words in review 49848 is 300
# Number of words in review 49849 is 300
# Number of words in review 49850 is 300
# Number of words in review 49851 is 300
# Number of words in review 49852 is 300
# Number of words in review 49853 is 300
# Number of words in review 49854 is 300
# Number of words in review 49855 is 300
# Number of words in review 49856 is 300
# Number of words in review 49857 is 300
# Number of words in review 49858 is 300
# Number of words in review 49859 is 300
# Number of words in review 49860 is 300
# Number of words in review 49861 is 300
# Number of words in review 49862 is 300
# Number of words in review 49863 is 300
# Number of words in review 49864 is 300
# Number of words in review 49865 is 300
# Number of words in review 49866 is 300
# Number of words in review 49867 is 300
# Number of words in review 49868 is 300
# Number of words in review 49869 is 300
# Number of words in review 49870 is 300
# Number of words in review 49871 is 300
# Number of words in review 49872 is 300
# Number of words in review 49873 is 300
# Number of words in review 49874 is 300
# Number of words in review 49875 is 300
# Number of words in review 49876 is 300
# Number of words in review 49877 is 300
# Number of words in review 49878 is 300
# Number of words in review 49879 is 300
# Number of words in review 49880 is 300
# Number of words in review 49881 is 300
# Number of words in review 49882 is 300
# Number of words in review 49883 is 300
# Number of words in review 49884 is 300
# Number of words in review 49885 is 300
# Number of words in review 49886 is 300
# Number of words in review 49887 is 300
# Number of words in review 49888 is 300
# Number of words in review 49889 is 300
# Number of words in review 49890 is 300
# Number of words in review 49891 is 300
# Number of words in review 49892 is 300
# Number of words in review 49893 is 300
# Number of words in review 49894 is 300
# Number of words in review 49895 is 300
# Number of words in review 49896 is 300
# Number of words in review 49897 is 300
# Number of words in review 49898 is 300
# Number of words in review 49899 is 300
# Number of words in review 49900 is 300
# Number of words in review 49901 is 300
# Number of words in review 49902 is 300
# Number of words in review 49903 is 300
# Number of words in review 49904 is 300
# Number of words in review 49905 is 300
# Number of words in review 49906 is 300
# Number of words in review 49907 is 300
# Number of words in review 49908 is 300
# Number of words in review 49909 is 300
# Number of words in review 49910 is 300
# Number of words in review 49911 is 300
# Number of words in review 49912 is 300
# Number of words in review 49913 is 300
# Number of words in review 49914 is 300
# Number of words in review 49915 is 300
# Number of words in review 49916 is 300
# Number of words in review 49917 is 300
# Number of words in review 49918 is 300
# Number of words in review 49919 is 300
# Number of words in review 49920 is 300
# Number of words in review 49921 is 300
# Number of words in review 49922 is 300
# Number of words in review 49923 is 300
# Number of words in review 49924 is 300
# Number of words in review 49925 is 300
# Number of words in review 49926 is 300
# Number of words in review 49927 is 300
# Number of words in review 49928 is 300
# Number of words in review 49929 is 300
# Number of words in review 49930 is 300
# Number of words in review 49931 is 300
# Number of words in review 49932 is 300
# Number of words in review 49933 is 300
# Number of words in review 49934 is 300
# Number of words in review 49935 is 300
# Number of words in review 49936 is 300
# Number of words in review 49937 is 300
# Number of words in review 49938 is 300
# Number of words in review 49939 is 300
# Number of words in review 49940 is 300
# Number of words in review 49941 is 300
# Number of words in review 49942 is 300
# Number of words in review 49943 is 300
# Number of words in review 49944 is 300
# Number of words in review 49945 is 300
# Number of words in review 49946 is 300
# Number of words in review 49947 is 300
# Number of words in review 49948 is 300
# Number of words in review 49949 is 300
# Number of words in review 49950 is 300
# Number of words in review 49951 is 300
# Number of words in review 49952 is 300
# Number of words in review 49953 is 300
# Number of words in review 49954 is 300
# Number of words in review 49955 is 300
# Number of words in review 49956 is 300
# Number of words in review 49957 is 300
# Number of words in review 49958 is 300
# Number of words in review 49959 is 300
# Number of words in review 49960 is 300
# Number of words in review 49961 is 300
# Number of words in review 49962 is 300
# Number of words in review 49963 is 300
# Number of words in review 49964 is 300
# Number of words in review 49965 is 300
# Number of words in review 49966 is 300
# Number of words in review 49967 is 300
# Number of words in review 49968 is 300
# Number of words in review 49969 is 300
# Number of words in review 49970 is 300
# Number of words in review 49971 is 300
# Number of words in review 49972 is 300
# Number of words in review 49973 is 300
# Number of words in review 49974 is 300
# Number of words in review 49975 is 300
# Number of words in review 49976 is 300
# Number of words in review 49977 is 300
# Number of words in review 49978 is 300
# Number of words in review 49979 is 300
# Number of words in review 49980 is 300
# Number of words in review 49981 is 300
# Number of words in review 49982 is 300
# Number of words in review 49983 is 300
# Number of words in review 49984 is 300
# Number of words in review 49985 is 300
# Number of words in review 49986 is 300
# Number of words in review 49987 is 300
# Number of words in review 49988 is 300
# Number of words in review 49989 is 300
# Number of words in review 49990 is 300
# Number of words in review 49991 is 300
# Number of words in review 49992 is 300
# Number of words in review 49993 is 300
# Number of words in review 49994 is 300
# Number of words in review 49995 is 300
# Number of words in review 49996 is 300
# Number of words in review 49997 is 300
# Number of words in review 49998 is 300
# Number of words in review 49999 is 300
# Number of words in review 50000 is 300

# %% [markdown]
# Number of labels

# %%
s = set(y)
print('The unique labels are', s)
print('The number of unique lables is', len(list(s)))
# Out:
# The unique labels are {0, 1}
# The number of unique lables is 2

# %%
len(y)
# Out:
# 50000

# %% [markdown]
# ### Print value of any one feature and it's label (2 Marks)

# %% [markdown]
# Feature value

# %%
X_padded[50]
# Out:
# array([  23,    2,  364,  499,    2,   72,   21,    2,   52, 3834,   37,
#         412,   50,   57,  824,  104,   36,   26,    2, 4834,  205,  704,
#           2,    2,    2,  769,  133,    2,    2, 1081,   31, 5352, 1966,
#        5445, 2274, 2478, 3365, 6508,    2, 1696,  611,  271,  145,    2,
#           2,  117, 2059,    2, 5966, 7189,  121,   29,    2, 1447,    2,
#          34,    2,  719,    2,    2,  339,   46,    2,    2, 1416, 7691,
#          29,  505,   49, 2388,  676,   83,    2,  707,  511,    2,   36,
#        2541,    2, 4969, 1428,    2,    2,    2,   50,   26, 8489,  806,
#           2,    2, 1143, 1850,    2,    2,  125,    2, 4122,    2,    2,
#         539,    2,    2, 3976,    2,    2,  368, 6498,   21,    2,  265,
#          29, 2906,  958,    2,  921,    2,    2,   49,    2,    2,   53,
#           2, 9370, 3547,   68,  290,    2, 6780,  429,   68,    2,   29,
#        1590, 7772, 5308,    2,   35, 3437, 6155,    2,   21,  164,  549,
#         341,    2,  170,    2,  570,   90,    2,    2,  466,    2,  643,
#        2031,   65,   75,   79,    2,  124,    2,   40,  111,    2,    2,
#         105,   37,  216,  638,    2,   84,  247,   74, 5249,  466,  111,
#           2,   98,  112,    2,    2,    2,  122,  594,   44,    2,  322,
#           2,  112,    2,    2,   38,  196,  475, 7189,    2,   31,  704,
#           2,    2,  182,  121,  141,  567,    2,  184, 2303,    2,   29,
#           2,   82,    2,  227,  185,    2,   30,   31,    2,    2, 8811,
#           2,    2, 1940,    2,    2,    2,    2,    2,    2, 1003, 1797,
#           2,    2, 8260,    2,    2,  227,    2,    2, 4375,   21,    2,
#        5372,   34,    2, 4070,    2,    2,  488,    2,    2,  331,  389,
#           2, 2274,    2,    2,   21, 2168, 5445,    2,  225,   49,  327,
#         228,    2,   73,    2,    2,    2,    2,    2,  226,  107,  634,
#           2,  277,    2,   51,   25,   97,    2,    2,    2,  482,   21,
#          45,   24, 7816,    2,    2,  135, 2274, 6883,   51,   29,  270,
#          46,    2,   81], dtype=int32)

# %% [markdown]
# Label value

# %%
y[50]
# Out:
# 1

# %%
#### Add your code here ####

# %% [markdown]
# ### Decode the feature value to get original sentence (2 Marks)

# %% [markdown]
# First, retrieve a dictionary that contains mapping of words to their index in the IMDB dataset

# %%
index = imdb.get_word_index()
reverse_index = dict([(value, key) for (key, value) in index.items()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# Now use the dictionary to get the original words from the encodings, for a particular sentence

# %%
decoded = " ".join( [reverse_index.get(i - 3, "#") for i in X_padded[50]] )
print(decoded)
# Out:
# on # low side # me but # good folk who live there no doubt think they are # god's own country # # # storyline here # # familiar one acclaimed international musician daniel suffers health breakdown # mid career goes back # # little village # northern sweden where he # born # by # local # # help out # # church choir he turns some unlikely talent into # class act # they enter # contest held # # # there are echoes sorry # # band players # # off # models # # girls # # dancers # # full monty but # course he causes plenty # emotional # # some # # more # villagers realise their worth # revolt against their # he faces hostile husbands # an increasingly dubious # but nothing except death # going # stop him # # despite # somewhat corny story we get # know # like many # # characters who come across # people rather than caricatures despite many # them being # # # did wonder about # wife # being # # so long  sweden # one country # # world where such violence # pretty strongly # he # also # bit young # be one # # bullies # # youth # # # # # # secret passion # # magazines # # bit # # stereotype but # realised by # falk # # michael # # simply wonderful # daniel # # but driven musician # there's some nice music # well # # # # # whole two hours # ending # what you make # # # guess but it's not spoiling # # say daniel achieves what he set out # do

# %% [markdown]
# Get the sentiment for the above sentence
# - positive (1)
# - negative (0)

# %%
if y[50]==1:
  print('The review is positive')
elif y[50]==0:
  print('The review is negative')
# Out:
# The review is positive

# %% [markdown]
# ### Define model (10 Marks)
# - Define a Sequential Model
# - Add Embedding layer
#   - Embedding layer turns positive integers into dense vectors of fixed size
#   - `tensorflow.keras` embedding layer doesn't require us to onehot encode our words, instead we have to give each word a unique integer number as an id. For the imdb dataset we've loaded this has already been done, but if this wasn't the case we could use sklearn LabelEncoder.
#   - Size of the vocabulary will be 10000
#   - Give dimension of the dense embedding as 100
#   - Length of input sequences should be 300
# - Add LSTM layer
#   - Pass value in `return_sequences` as True
# - Add a `TimeDistributed` layer with 100 Dense neurons
# - Add Flatten layer
# - Add Dense layer

# %%
X_padded = X_padded[0:10000]
y = y[0:10000]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, random_state=142, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8000, 300), (2000, 300), (8000,), (2000,))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers.embeddings import Embedding
from keras.layers import Flatten
model = Sequential()

# %%
model.add(Embedding(input_dim=10000, output_dim=100, input_length=300))

# %%
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed
model.add(LSTM(100, return_sequences=True))

# %% [markdown]
# ### Compile the model (2 Marks)
# - Use Optimizer as Adam
# - Use Binary Crossentropy as loss
# - Use Accuracy as metrics

# %%
model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])

# %% [markdown]
# ### Print model summary (2 Marks)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 100)          1000000
#
#  lstm (LSTM)                 (None, 300, 100)          80400
#
# =================================================================
# Total params: 1,080,400
# Trainable params: 1,080,400
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Fit the model (2 Marks)

# %% [markdown]
# ### Evaluate model (2 Marks)

# %%
model.fit(X_train, y_train, epochs = 10, batch_size=32, verbose=2)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-78b88c389912> in <module>()
# ----> 1 model.fit(X_train, y_train, epochs = 10, batch_size=32, verbose=2)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 919, in compute_loss
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.7/dist-packages/keras/losses.py", line 1932, in binary_crossentropy
#         backend.binary_crossentropy(y_true, y_pred, from_logits=from_logits),
#     File "/usr/local/lib/python3.7/dist-packages/keras/backend.py", line 5262, in binary_crossentropy
#         bce = target * tf.math.log(output + epsilon())
#
#     ValueError: Dimensions must be equal, but are 32 and 100 for '{{node binary_crossentropy/mul}} = Mul[T=DT_FLOAT](binary_crossentropy/Cast, binary_crossentropy/Log)' with input shapes: [32], [32,300,100].

# %% [markdown]
# ### Predict on one sample (2 Marks)

# %%
#### Add your code here ####
